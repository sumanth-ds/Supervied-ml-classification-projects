# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns',None)
data = pd.read_csv("Energy_and_Water_Data_Disclosure_for_Local_Law_84_2017__Data_for_Calendar_Year_2016_.csv")
data.head()
# Out:
#    Order  Property Id                                 Property Name  \
# 0      1        13286                                       201/205
# 1      2        28400                    NYP Columbia (West Campus)
# 2      3      4778226                                 MSCHoNY North
# 3      4      4778267  Herbert Irving Pavilion & Millstein Hospital
# 4      5      4778288                               Neuro Institute
#
#   Parent Property Id        Parent Property Name BBL - 10 digits  \
# 0              13286                     201/205      1013160001
# 1              28400  NYP Columbia (West Campus)      1021380040
# 2              28400  NYP Columbia (West Campus)      1021380030
# 3              28400  NYP Columbia (West Campus)      1021390001
# 4              28400  NYP Columbia (West Campus)      1021390085
#
#   NYC Borough, Block and Lot (BBL) self-reported  \
# 0                                     1013160001
# 1                                   1-02138-0040
# ...

# %%
data.reset_index(drop = True)
# Out:
#        Order  Property Id                                 Property Name  \
# 0          1        13286                                       201/205
# 1          2        28400                    NYP Columbia (West Campus)
# 2          3      4778226                                 MSCHoNY North
# 3          4      4778267  Herbert Irving Pavilion & Millstein Hospital
# 4          5      4778288                               Neuro Institute
# ...      ...          ...                                           ...
# 11741  14988      4940453                     Advanced: 24 Monroe Place
# 11742  14989      4940416   Advanced: 150 Joralemon St / 124 Clinton St
# 11743  14990      4628296                         (9267) - 267 Sixth St
# 11744  14991      4940464               Advanced: 27 Prospect Park West
# 11745  14993      4952165                        Tryad: 420 Clinton Ave
#
#                         Parent Property Id  \
# 0                                    13286
# ...

# %%
for column in data.columns:
    data[column].replace("Not Available",np.nan , inplace = True)
data.head()
# Out:
#    Order  Property Id                                 Property Name  \
# 0      1        13286                                       201/205
# 1      2        28400                    NYP Columbia (West Campus)
# 2      3      4778226                                 MSCHoNY North
# 3      4      4778267  Herbert Irving Pavilion & Millstein Hospital
# 4      5      4778288                               Neuro Institute
#
#   Parent Property Id        Parent Property Name BBL - 10 digits  \
# 0              13286                     201/205      1013160001
# 1              28400  NYP Columbia (West Campus)      1021380040
# 2              28400  NYP Columbia (West Campus)      1021380030
# 3              28400  NYP Columbia (West Campus)      1021390001
# 4              28400  NYP Columbia (West Campus)      1021390085
#
#   NYC Borough, Block and Lot (BBL) self-reported  \
# 0                                     1013160001
# 1                                   1-02138-0040
# ...

# %%
null_columns = []


for column in data.columns:
    print(column , data[column].isnull().sum() ,"---", end = " ")
    print( data[column].isnull().sum()/len(data)*100)
    if data[column].isnull().sum()/len(data)*100 > float(20):
        null_columns.append(column)
# Out:
# Order 0 --- 0.0
# Property Id 0 --- 0.0
# Property Name 0 --- 0.0
# Parent Property Id 0 --- 0.0
# Parent Property Name 0 --- 0.0
# BBL - 10 digits 11 --- 0.09364890175378852
# NYC Borough, Block and Lot (BBL) self-reported 11 --- 0.09364890175378852
# NYC Building Identification Number (BIN) 162 --- 1.379192916737613
# Address 1 (self-reported) 0 --- 0.0
# Address 2 11539 --- 98.23769793972417
# Postal Code 0 --- 0.0
# Street Number 124 --- 1.0556785288608888
# Street Name 122 --- 1.0386514558147455
# Borough 118 --- 1.0045973097224588
# DOF Gross Floor Area 118 --- 1.0045973097224588
# Primary Property Type - Self Selected 0 --- 0.0
# List of All Property Use Types at Property 0 --- 0.0
# Largest Property Use Type 2 --- 0.017027073046143367
# Largest Property Use Type - Gross Floor Area (ft²) 2 --- 0.017027073046143367
# 2nd Largest Property Use Type 8005 --- 68.15085986718883
# 2nd Largest Property Use - Gross Floor Area (ft²) 8005 --- 68.15085986718883
# ...

# %%
null_columns
# Out:
# ['Address 2',
#  '2nd Largest Property Use Type',
#  '2nd Largest Property Use - Gross Floor Area (ft²)',
#  '3rd Largest Property Use Type',
#  '3rd Largest Property Use Type - Gross Floor Area (ft²)',
#  'Metered Areas  (Water)',
#  'Fuel Oil #1 Use (kBtu)',
#  'Fuel Oil #2 Use (kBtu)',
#  'Fuel Oil #4 Use (kBtu)',
#  'Fuel Oil #5 & 6 Use (kBtu)',
#  'Diesel #2 Use (kBtu)',
#  'District Steam Use (kBtu)',
#  'Water Use (All Water Sources) (kgal)',
#  'Water Intensity (All Water Sources) (gal/ft²)']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11746 entries, 0 to 11745
# Data columns (total 60 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Order                                                       11746 non-null  int64
#  1   Property Id                                                 11746 non-null  int64
#  2   Property Name                                               11746 non-null  object
#  3   Parent Property Id                                          11746 non-null  object
#  4   Parent Property Name                                        11746 non-null  object
#  5   BBL - 10 digits                                             11735 non-null  object
#  6   NYC Borough, Block and Lot (BBL) self-reported              11735 non-null  object
# ...

# %%
data["ENERGY STAR Score"].unique()
# Out:
# array(['100', '55', nan, '93', '1', '80', '72', '67', '40', '99', '12',
#        '88', '89', '86', '73', '71', '74', '19', '84', '78', '81', '6',
#        '77', '3', '59', '23', '61', '58', '85', '66', '45', '2', '51',
#        '17', '34', '22', '43', '13', '96', '98', '36', '69', '68', '65',
#        '26', '95', '49', '39', '29', '14', '15', '16', '53', '94', '8',
#        '33', '32', '91', '25', '24', '11', '21', '30', '42', '41', '79',
#        '97', '35', '90', '28', '37', '31', '4', '75', '64', '9', '92',
#        '62', '38', '76', '20', '54', '87', '70', '46', '56', '63', '48',
#        '10', '60', '82', '44', '83', '52', '18', '7', '5', '27', '57',
#        '47', '50'], dtype=object)

# %%
data["Property Name"].unique()
# Out:
# array(['201/205', 'NYP Columbia (West Campus)', 'MSCHoNY North', ...,
#        '(9267) - 267 Sixth St', 'Advanced: 27 Prospect Park West',
#        'Tryad: 420 Clinton Ave'], dtype=object)

# %%
null_columns.append("Order")
data.drop(null_columns ,inplace = True , axis = 1)

# %%
data["Parent Property Name"].unique()
# Out:
# array(['201/205', 'NYP Columbia (West Campus)',
#        'NYP Cornell (East Campus)', 'North Shore Towers', 'Cadman Towers',
#        'STATEN ISLAND UNIVERSITY HOSPITAL Seaview', 'Barnard College',
#        '720-730 Ft. Washington Owners Corp.', 'Park 76th Street Inc.',
#        '560 Riverside Drive', 'Meyer Hall', 'MCKINLEY',
#        'Metro North - 420-440 East 102 St.',
#        'Benjamin: 86-02 208 St (Parent)',
#        'Benjamin: 206-10 86 Rd (Parent)',
#        'Benjamin: 209-30 86 Drive (Parent)',
#        'Benjamin: 209-31 86 Drive (Parent)',
#        'Columbia University (morningside)',
#        'Columbia University Medical Center', 'Pace University NYC Campus',
#        'Memorial Sloan Kettering Cancer Center 1',
#        'New York University: Washington Square',
#        'New York Eye & Ear Infirmary', '435 W 119 and 434 W 120',
#        'College of Mt St Vincent', '1 hoyt st', '601 W 112 and 600 W 113',
#        '430 W 119 ET AL', 'Manhattan Campus',
# ...

# %%
data["Street Name"].unique()
# Out:
# array(['3 AVENUE', 'FT WASHINGTON AVENUE', 'BROADWAY', ...,
#        'SEGUINE AVENUE', 'VETERANS ROAD WEST', 'ELLIS STREET'],
#       dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11746 entries, 0 to 11745
# Data columns (total 45 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Property Id                                                 11746 non-null  int64
#  1   Property Name                                               11746 non-null  object
#  2   Parent Property Id                                          11746 non-null  object
#  3   Parent Property Name                                        11746 non-null  object
#  4   BBL - 10 digits                                             11735 non-null  object
#  5   NYC Borough, Block and Lot (BBL) self-reported              11735 non-null  object
#  6   NYC Building Identification Number (BIN)                    11584 non-null  object
# ...

# %%
for column in data.columns:
    print(column , data[column].isnull().sum() ,"---", end = " ")
    print( data[column].isnull().sum()/len(data)*100)
# Out:
# Property Id 0 --- 0.0
# Property Name 0 --- 0.0
# Parent Property Id 0 --- 0.0
# Parent Property Name 0 --- 0.0
# BBL - 10 digits 11 --- 0.09364890175378852
# NYC Borough, Block and Lot (BBL) self-reported 11 --- 0.09364890175378852
# NYC Building Identification Number (BIN) 162 --- 1.379192916737613
# Address 1 (self-reported) 0 --- 0.0
# Postal Code 0 --- 0.0
# Street Number 124 --- 1.0556785288608888
# Street Name 122 --- 1.0386514558147455
# Borough 118 --- 1.0045973097224588
# DOF Gross Floor Area 118 --- 1.0045973097224588
# Primary Property Type - Self Selected 0 --- 0.0
# List of All Property Use Types at Property 0 --- 0.0
# Largest Property Use Type 2 --- 0.017027073046143367
# Largest Property Use Type - Gross Floor Area (ft²) 2 --- 0.017027073046143367
# Year Built 0 --- 0.0
# Number of Buildings - Self-reported 0 --- 0.0
# Occupancy 0 --- 0.0
# Metered Areas (Energy) 57 --- 0.485271581815086
# ENERGY STAR Score 2104 --- 17.91248084454282
# ...

# %%
data.drop_duplicates(inplace = True )

# %%
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11741    False
# 11742    False
# 11743    False
# 11744    False
# 11745    False
# Length: 11746, dtype: bool

# %%
data["Year Built"].unique()
# Out:
# array([1963, 1969, 1924, 1971, 1932, 1974, 1903, 1950, 1907, 1939, 1911,
#        1964, 1962, 1973, 1952, 1897, 1996, 1906, 1898, 1908, 1999, 1934,
#        1925, 1935, 1961, 1910, 1980, 1977, 1988, 1987, 1927, 1930, 2010,
#        1909, 1920, 1914, 2004, 1998, 1995, 1929, 1928, 1976, 1970, 1905,
#        1940, 2009, 2003, 2006, 1833, 1966, 1981, 1959, 1960, 1992, 1896,
#        1972, 2001, 2012, 1986, 1951, 1895, 1894, 1893, 1891, 1901, 2011,
#        1848, 1956, 1967, 1915, 2000, 2013, 2007, 1965, 1978, 1990, 1953,
#        1955, 1968, 1954, 2014, 1900, 1994, 1947, 1887, 2005, 1888, 1957,
#        1975, 1991, 1984, 2008, 1949, 1921, 1985, 1931, 1882, 1958, 1902,
#        1997, 1989, 1983, 1916, 1917, 1904, 1913, 1982, 1926, 1836, 1827,
#        2002, 1922, 1912, 1600, 1936, 1918, 1883, 1890, 1845, 1865, 1933,
#        1979, 1938, 1923, 2016, 1886, 1874, 1880, 1860, 1885, 1919, 1941,
#        1873, 1857, 1942, 1899, 1850, 1937, 1945, 1875, 1867, 1870, 1877,
# ...

# %%
data[data["Year Built"] == 2000]["ENERGY STAR Score"].unique()
# Out:
# array([nan, '3', '80', '24', '59', '40', '2', '38', '36', '10', '58',
#        '33', '72', '19', '7', '34', '26', '82', '22', '11', '4', '1',
#        '99', '70', '9', '32', '29', '30', '100', '89', '71', '27', '48',
#        '35', '55', '49', '41', '65', '95', '75', '74', '25', '47', '83'],
#       dtype=object)

# %%
def null_imputation(data):
    for column in data.columns:
        if type(data[column]) == np.number:
            data[column].fillna(data[column].median() , inplace = True)
        else:
            data[column].fillna(data[column].mode() , inplace = True)
    return data
data = null_imputation(data)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11746 entries, 0 to 11745
# Data columns (total 45 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Property Id                                                 11746 non-null  int64
#  1   Property Name                                               11746 non-null  object
#  2   Parent Property Id                                          11746 non-null  object
#  3   Parent Property Name                                        11746 non-null  object
#  4   BBL - 10 digits                                             11735 non-null  object
#  5   NYC Borough, Block and Lot (BBL) self-reported              11735 non-null  object
#  6   NYC Building Identification Number (BIN)                    11584 non-null  object
# ...

# %%
for column in

# %%
def boxplot(column):
    sns.boxplot(column)
    plt.title()
    plt.show()
for column in data.select_dtypes(exclude = ["object"]).columns:
    #boxplot(data[column])
    sns.boxplot(column)
    plt.title(column)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 7
#       4     plt.show()
#       5 for column in data.select_dtypes(exclude = ["object"]).columns:
#       6     #boxplot(data[column])
# ----> 7     sns.boxplot(column)
#       8     plt.title(column)
#       9     plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2231, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2224 def boxplot(
#    2225     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2226     orient=None, color=None, palette=None, saturation=.75, width=.8,
#    2227     dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None,
#    2228     **kwargs
#    2229 ):
# -> 2231     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
# ...

# %%
data.head()
# Out:
#    Order  Property Id                                 Property Name  \
# 0      1        13286                                       201/205
# 1      2        28400                    NYP Columbia (West Campus)
# 2      3      4778226                                 MSCHoNY North
# 3      4      4778267  Herbert Irving Pavilion & Millstein Hospital
# 4      5      4778288                               Neuro Institute
#
#   Parent Property Id        Parent Property Name BBL - 10 digits  \
# 0              13286                     201/205      1013160001
# 1              28400  NYP Columbia (West Campus)      1021380040
# 2              28400  NYP Columbia (West Campus)      1021380030
# 3              28400  NYP Columbia (West Campus)      1021390001
# 4              28400  NYP Columbia (West Campus)      1021390085
#
#   NYC Borough, Block and Lot (BBL) self-reported  \
# 0                                     1013160001
# 1                                   1-02138-0040
# ...
